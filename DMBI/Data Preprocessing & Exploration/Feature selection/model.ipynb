# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df =pd.read_csv('winequalityN.csv')

# %%
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]

# %%
column_names = df.columns

# %%
df['type'] = [0 if color == 'white' else 1 for color in df['type']]

# %%
df
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            7.0             0.270         0.36            20.7
# 1        0            6.3             0.300         0.34             1.6
# 2        0            8.1             0.280         0.40             6.9
# 3        0            7.2             0.230         0.32             8.5
# 4        0            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6492     1            6.2             0.600         0.08             2.0
# 6493     1            5.9             0.550         0.10             2.2
# 6494     1            6.3             0.510         0.13             2.3
# 6495     1            5.9             0.645         0.12             2.0
# 6496     1            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]

# %%
scaler = StandardScaler()

# %%
scaler.fit(df)
# Out:
# StandardScaler()

# %%
df = scaler.transform(df)

# %%
df
# Out:
# array([[-0.57136659, -0.16702991, -0.42330275, ..., -0.54579101,
#         -1.41855821,  0.20799905],
#        [-0.57136659, -0.70688264, -0.24108295, ..., -0.27697861,
#         -0.83161516,  0.20799905],
#        [-0.57136659,  0.68131011, -0.36256282, ..., -0.61299411,
#         -0.32852111,  0.20799905],
#        ...,
#        [ 1.75018984, -0.70688264,  1.03445559, ...,  1.47030196,
#          0.42611996,  0.20799905],
#        [ 1.75018984, -1.01536992,  1.85444466, ...,  1.20148957,
#         -0.2446721 , -0.93722961],
#        [ 1.75018984, -0.9382481 , -0.18034302, ...,  0.86547407,
#          0.42611996,  0.20799905]])

# %%
df = pd.DataFrame(df, columns=column_names)

# %%
df
# Out:
#           type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0    -0.571367      -0.167030         -0.423303     0.284180        3.206483
# 1    -0.571367      -0.706883         -0.241083     0.146489       -0.808012
# 2    -0.571367       0.681310         -0.362563     0.559560        0.305958
# 3    -0.571367      -0.012786         -0.666262     0.008799        0.642251
# 4    -0.571367      -0.012786         -0.666262     0.008799        0.642251
# ...        ...            ...               ...          ...             ...
# 6492  1.750190      -0.784004          1.581115    -1.643483       -0.723939
# 6493  1.750190      -1.015370          1.277415    -1.505793       -0.681902
# 6494  1.750190      -0.706883          1.034456    -1.299258       -0.660884
# 6495  1.750190      -1.015370          1.854445    -1.368103       -0.723939
# 6496  1.750190      -0.938248         -0.180343     1.041476       -0.387646
#
#       chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# 0     -0.315173             0.815565              0.959976  2.102214
# 1     -0.200996            -0.931107              0.287618 -0.232332
# 2     -0.172452            -0.029599             -0.331660  0.134525
# 3      0.055902             0.928254              1.243074  0.301278
# 4      0.055902             0.928254              1.243074  0.301278
# ...         ...                  ...                   ...       ...
# 6492   0.969318             0.083090             -1.269422  0.067824
# 6493   0.170079             0.477500             -1.145567  0.141195
# 6494   0.569698            -0.085943             -1.340197  0.347969
# 6495   0.541154             0.083090             -1.269422  0.257923
# 6496   0.312800            -0.705730             -1.304809  0.264593
#
#             pH  sulphates   alcohol   quality
# 0    -1.358722  -0.545791 -1.418558  0.207999
# 1     0.507693  -0.276979 -0.831615  0.207999
# 2     0.258838  -0.612994 -0.328521  0.207999
# 3    -0.176659  -0.881807 -0.496219  0.207999
# 4    -0.176659  -0.881807 -0.496219  0.207999
# ...        ...        ...       ...       ...
# 6492  1.440901   0.327849  0.006875 -0.937230
# 6493  1.876398        NaN  0.593818  0.207999
# 6494  1.254259   1.470302  0.426120  0.207999
# 6495  2.187467   1.201490 -0.244672 -0.937230
# 6496  1.067618   0.865474  0.426120  0.207999
#
# [6497 rows x 13 columns]
