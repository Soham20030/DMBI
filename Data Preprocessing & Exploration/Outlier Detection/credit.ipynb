# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('creditcard.csv')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
# df.isnull().sum().to_string()

# %%
mean = df['V1'].mean()
std_dev = df['V1'].std()

# %%
df['Z_score'] = (df['V1'] - mean) / std_dev

# %%
threshold = 3

# %%
outliers = df[df['Z_score'].abs() > threshold]

# %%
print("Outliers detected using Z-score method:")
print(outliers)
# Out:
# Outliers detected using Z-score method:
#             Time         V1         V2         V3        V4         V5  \
# 164        103.0  -6.093248 -12.114213  -5.694973  3.294389  -1.413792
# 1158       905.0  -6.169664   6.118940  -1.667775 -1.206991  -0.021373
# 1632      1264.0 -11.140706  -9.612726 -12.389545  6.013346 -32.092129
# 2464      2029.0 -12.168192 -15.732974  -0.376474  3.792613  10.658654
# 2682      2223.0  -7.546256   3.051033  -0.524684  1.005228   0.040486
# ...          ...        ...        ...        ...       ...        ...
# 284561  172558.0  -6.491016   5.700607  -6.421237 -0.971126  -2.902874
# 284649  172642.0 -11.946976   9.772660  -8.006237 -2.498596  -4.229520
# 284772  172760.0  -6.713826   2.369104  -3.534768 -0.368259  -1.721030
# 284795  172778.0 -12.516732  10.187818  -8.476671 -2.510473  -4.586669
# 284802  172786.0 -11.881118  10.071785  -9.834783 -2.066656  -5.364473
#
#                V6         V7         V8        V9  ...       V22       V23  \
# 164      4.776000   4.808426  -0.228197 -0.525896  ... -2.264037 -3.553381
# 1158    -1.208458   2.184989  -1.512188  6.450992  ...  0.261435  0.136166
# 1632    21.393069  34.303177  -7.520784 -1.925732  ...  1.366110 -2.925888
# 2464    -7.465603  -6.907038   1.573722  0.058164  ... -0.910516  0.010468
# 2682     2.751676  -6.267406 -19.176657  1.049976  ... -3.053597  2.648404
# ...           ...        ...        ...       ...  ...       ...       ...
# 284561  -0.713295  -3.470382   5.332066 -0.143787  ... -1.321234  0.617429
# 284649  -1.320039  -3.259766   5.059956  4.870093  ... -1.529035  0.838689
# 284772  -1.322808  -0.190876   0.891149  2.068476  ...  0.994246 -0.002140
# 284795  -1.394465  -3.632516   5.498583  4.893089  ... -1.565026  0.890675
# 284802  -2.606837  -4.918215   7.305334  1.914428  ...  0.111864  1.014480
#
#              V24       V25       V26       V27       V28   Amount  Class  \
# 164     1.215279 -0.406073 -0.653384 -0.711222  0.672900  3828.04      0
# 1158    0.413380  0.666632 -0.530568  2.464962  0.365892     0.89      0
# 1632    0.843551  0.746267  0.801387  3.852046  4.157934  7712.43      0
# 2464   -0.097246 -0.329918  0.225916  0.201802 -2.368534   120.00      0
# 2682    0.429294  0.300704 -0.273082  1.300662 -0.641413    29.90      0
# ...          ...       ...       ...       ...       ...      ...    ...
# 284561 -0.559790  0.515726  0.232630 -0.113612 -0.056250    16.98      0
# 284649 -1.249172  1.714495  0.314623  2.112848  1.234408    10.74      0
# 284772 -0.072979 -0.167159 -0.387271 -2.616341  0.474584    19.59      0
# 284795 -1.253276  1.786717  0.320763  2.090712  1.232864     9.87      0
# 284802 -0.509348  1.436807  0.250034  0.943651  0.823731     0.77      0
#
#          Z_score
# 164    -3.110870
# 1158   -3.149884
# 1632   -5.687819
# 2464   -6.212395
# 2682   -3.852694
# ...          ...
# 284561 -3.313948
# 284649 -6.099455
# 284772 -3.427702
# 284795 -6.390340
# 284802 -6.065831
#
# [3701 rows x 32 columns]

# %%
sns.boxplot(x=df['V1'])
plt.show()
